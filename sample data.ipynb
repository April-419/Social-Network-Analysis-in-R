# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder #convert categorical variables into numerical variables
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics #evaluate the performance of machine learning models

# %%
#Loading data from csv file to a Pandas DataFrame
data = pd.read_csv("/Users/jianingjin/Downloads/venmo_cleaned.csv")
# Out:
# /var/folders/6j/4hpwlvm53rb7c9ytxmxhmnv00000gn/T/ipykernel_22962/42872284.py:2: DtypeWarning: Columns (9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/jianingjin/Downloads/venmo_cleaned.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7075081 entries, 0 to 7075080
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   payment.id                       float64
#  1   payment.date_completed           object
#  2   payment.target.user.username     object
#  3   payment.target.user.is_group     object
#  4   payment.target.user.is_active    object
#  5   payment.target.user.is_blocked   object
#  6   payment.target.user.id           float64
#  7   payment.target.user.date_joined  object
#  8   payment.actor.username           object
#  9   payment.actor.is_group           object
#  10  payment.actor.is_active          object
#  11  payment.actor.is_blocked         object
#  12  payment.actor.id                 float64
#  13  payment.actor.date_joined        object
#  14  payment.note                     object
#  15  payment.action                   object
# ...

# %%
data.head()
# Out:
#      payment.id payment.date_completed payment.target.user.username  \
# 0  2.540405e+18    2018-08-07T02:11:16                    kimsionie
# 1  2.540405e+18    2018-08-07T02:11:16                  Kari-Joel-1
# 2  2.540405e+18    2018-08-07T02:11:15                        JDR88
# 3  2.540405e+18    2018-08-07T02:11:15                   Dion-Nunez
# 4  2.540405e+18    2018-08-07T02:11:15                  AlecJameson
#
#   payment.target.user.is_group payment.target.user.is_active  \
# 0                        False                          True
# 1                        False                          True
# 2                        False                          True
# 3                        False                          True
# 4                        False                          True
#
#   payment.target.user.is_blocked  payment.target.user.id  \
# 0                          False            2.082497e+18
# 1                          False            2.538731e+18
# ...
